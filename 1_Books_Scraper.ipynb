# %% [markdown]
# # Book Scraper
# This scraper fetches Arabic books data from [Abjjad](http://abjjad.com) website by 2 methods.
#
#
#
# **First method: **
#
# You can use it if you want to collect the data by yourself, and you can decide which categories of books you want to collect. The general steps of this method are:
#
# 1. Open a list (category) of books (like language, arts, biography...etc)
#
# 2. Open all pages in the list
#
# 3. Getting all books URLs within the list
#
# 4. Scrape each book data and save it into a dataframe and csv
#
# **Second method:**
#
# You can use it if you have a list of books URLs and you want to scrape the books directly. The examples of the ***input*** of this method are in [Data/Lists_of_Links](https://github.com/iHaifaa/Arabic_Books_Recommendation_System/tree/main/Data/Lists_of_Links) folder.
#
# The features of the obtained data are:
#
# | Feature | Description |
# |:----------------:|:----------------------------------------------------------------------------------------------:|
# | ISBN | ISBN or ISBN 13 of the book. |
# | Title | The whole title of the book. |
# | Author | The author name/s. Like the main author, co-author, and translator. |
# | Authors_Number | Number of authors, it is 1 if the book has only one author. |
# | Description | The text description of the book, taken from the book summary or written by an admin. |
# | Genres | The category of the book. |
# | Average_Ratings | Average rate for a given book. |
# | Reviews_Number | Number of written reviews by users. |
# | Quotes_Number | Number of quotes taken from the book and published by users. |
# | Community_Size | Number of users who added the book to their shelves (as read, currently reading, or to_read) |
# | Pages_Number | Amount of pages per title. |
# | Editions | Number of different editions for the book, not the current one. |
# | Publication_Year | Year of the first publication. |
# | Publisher | Publisher's name. |
# | URL | Direct link to the book's page on Abjjad. |
# | Cover_URL | Direct link to the book's image on Abjjad. |
#
# Finally, I provided a sample of the ***output*** of this process in [Data/Books_Data](https://github.com/iHaifaa/Arabic_Books_Recommendation_System/tree/main/Data/Books_Data) folder and called **Books_Category9.csv** and **Books_Category9.csv** .

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions

from lxml import html
#from time import sleep

import pandas as pd

import csv

# %%
browser = webdriver.Firefox()

browser.get('https://www.abjjad.com/search')

browser.find_element_by_xpath('/html/body/header/div[2]/nav[2]/ul/li[2]/div/span').click() # go to books tab

browser.find_element_by_xpath('/html/body/header/div[2]/nav[2]/ul/li[2]/div/div/a[1]').click() # go to all books option

# %%
'''signin = browser.find_element_by_xpath("/html/body/header/div[2]/nav[1]/ul/li[3]/a")
signin.click()

email = browser.find_element_by_xpath("//*[@id='Email']")
email.send_keys("your email") 

password = browser.find_element_by_xpath("//*[@id='Password']")
password.send_keys("your password")

submit = browser.find_element_by_xpath("/html/body/div[2]/div/div/div/form[1]/section/fieldset/ol/li[3]/input")
submit.click()

sleep(3)'''
# Out:
# 'signin = browser.find_element_by_xpath("/html/body/header/div[2]/nav[1]/ul/li[3]/a")\nsignin.click()\n\nemail = browser.find_element_by_xpath("//*[@id=\'Email\']")\nemail.send_keys("your email") \n\npassword = browser.find_element_by_xpath("//*[@id=\'Password\']")\npassword.send_keys("your password")\n\nsubmit = browser.find_element_by_xpath("/html/body/div[2]/div/div/div/form[1]/section/fieldset/ol/li[3]/input")\nsubmit.click()\n\nsleep(3)'

# %% [markdown]
# ## Essential functions

# %% [markdown]
# ### Books Metadata

# %%
def get_isbn():
    raw_html = browser.page_source
    html_source = html.fromstring(raw_html)
    try:
        return browser.find_element_by_css_selector('.about > ul:nth-child(2) > li:nth-child(3)').text
    except:
        return None

# %%
def get_title():
    try:
     #return browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div[1]/div/div/div[3]/h1').text # book title
     return browser.find_element_by_css_selector('.bookeditbadge > h1:nth-child(1)').text
    except: 
        return None

# %%
def get_author():
    try:
        return browser.find_element_by_class_name('author').text
    except:
        return None

# %%
def get_authors():
    try:
        return browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div[4]/div/ul/li[5]').text 
    except:
        return None

# %%
def get_description():
    try:
        raw_html = browser.page_source
        html_source = html.fromstring(raw_html)
        text_1 = ''.join(html_source.xpath("//span[@class='content']/text()")).strip()
        text_2 = ''.join(html_source.xpath("//span[@class='guts']/text()")).strip()
        return f'{text_1} {text_2}'
    except:
        return None

# %%
def get_genre():
    try:
        return browser.find_element_by_css_selector('.cats > ul:nth-child(2)').text # genre
    except:
        return None

# %%
def get_year():
    try:
        return browser.find_element_by_css_selector('.about > ul:nth-child(2) > li:nth-child(1)').text
    except:
        return None

# %%
def get_pages():
    try:
        return browser.find_element_by_css_selector('.about > ul:nth-child(2) > li:nth-child(2)').text
    except:
        return None

# %%
def get_publisher():
    try:
        return browser.find_element_by_css_selector('.about > ul:nth-child(2) > li:nth-child(4) > a:nth-child(1)').text # publisher
    except:
        return None

# %%
def get_rating():
    try:
        return browser.find_element_by_class_name('rating').text # number of ratings
    except:
        return None

# %%
def get_reviews():
    try:
        return browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div[4]/div/ul/li[1]').text
    except: 
        return None

# %%
def get_quotes():
    try:
        return browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div[4]/div/ul/li[2]').text
    except:
        return None

# %%
def get_community():
    try:
        return browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div[4]/div/ul/li[3]').text
    except:
        return None

# %%
def get_actual_readers():
    browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div[1]/div/div/div[3]/div[3]/div/span').click()
    try:
        return browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div[1]/div/div/div[4]/div[3]/div/ul/li[4]').text # readers
    except:
        return None

# %%
def get_editions():
    try:
        return browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div[4]/div/ul/li[4]').text # number of editions
    except:
        return None

# %%
def get_img():
    try:
        return browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div[1]/div/div/div[1]/a/img').get_attribute("src") #img
    except:
        return None

# %% [markdown]
# ### Scraper function

# %%
books_dataset = pd.DataFrame(columns = ['ISBN', 'Title', 'Author', 'Authors_Number', 'Description', 'Genres', 'Average_Ratings', 'Reviews_Number', 'Quotes_Number', 'Community_Size', 'Pages_Number', 'Editions', 'Publication_Year', 'Publisher', 'URL', 'Cover_URL']) #'Readers_Number',

# %%
def book_scraper(book_index): 
    #===========================================================
    try:
        more = browser.find_element_by_xpath("//div/span[@class='a h']") 
        more.click()
    except:
        print("There is no more button")

    # ================= Appending all metadata to the dataframe =================
    global books_dataset 
    books_dataset = books_dataset.append({'ISBN':get_isbn(), 'Title':get_title(), 'Author':get_author(), 'Authors_Number':get_authors(), 
                                        'Description':get_description(), 'Genres':get_genre(), 'Average_Ratings':get_rating(), 
                                        'Reviews_Number':get_reviews(), 'Quotes_Number':get_quotes(), 'Community_Size':get_community(),                                                             'Pages_Number':get_pages(),'Editions':get_editions(), 'Publication_Year':get_year(), 
                                        'Publisher':get_publisher(), 'URL':browser.current_url, 'Cover_URL':get_img()}, ignore_index=True)
    
    books_dataset.to_csv('Data/Books_Data/Books_Category9.csv')
    
    print('================= Book number: ', book_index, ' was successfully scraped =================')

# %% [markdown]
# ## Method 1: Scrape by browseing website's categories

# %% [markdown]
# ### Pager function

# %%
# To iterate over the category pages

def pager(category_no):
    
    print('===================== Category Number: ', category_no, '=====================')

    # ================= Open all pages within a category =================
    while True:
        try:
            next_page_btn =browser.find_elements_by_xpath("/html/body/div[2]/div/div[1]/div[2]/div[2]/div[2]/div/div[2]")
            element =WebDriverWait(browser,5).until(expected_conditions.element_to_be_clickable((By.XPATH,
            '/html/body/div[2]/div/div[1]/div[2]/div[2]/div[2]/div/div[2]')))
            browser.execute_script("return arguments[0].scrollIntoView();", element)
            element.click()        
        except:
            #if len(next_page_btn) <1:
            print("No more pages left")
            break

# %%
# We will use the first 27 categories of books from Abjjad
# So, we collect the categories xpath to open the links of categories
# Then, getting books urls

for i in range(1,28):
    browser.find_element_by_xpath('/html/body/header/div[2]/nav[2]/ul/li[2]/div/span').click() # go to books tab
    browser.find_element_by_xpath('/html/body/header/div[2]/nav[2]/ul/li[2]/div/div/a[1]').click() # go to all books option
    browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div[2]/div[2]/div[1]/section/div/ul/li['+str(i)+']').click() # open a category page
    #print("Number of books in this category is: ", browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div[2]/div[1]/p/span').text)
    pager(i)

    # ================= Collect all books urls within a specific category =================
    urls = browser.find_elements_by_css_selector("div.thebookbadge h5 a")
    list_of_urls = []
    for url in urls:
        #print(url.get_attribute("href")) 
        list_of_urls.append(url.get_attribute("href"))
        
    # ================== Save the list of urls into a text file ===================
    with open('Data/Lists_of_Links/list_of_urls'+str(i)+'.txt', "w") as output:
        output.write(str(list_of_urls))
    
    # ================= Scrape each book by its url within a category =================
    for book_index, book in enumerate(list_of_urls):
        # Open the book link
        try:
            browser.get(book)
        # Call a function to scrape each book metadata by pass the previous list
            book_scraper(book_index+1)
        except:
            print('The book number:', book_index, 'was cancelled due to an exception')
# Out:
# on
# The book number: 893 was cancelled due to an exception
# The book number: 894 was cancelled due to an exception
# The book number: 895 was cancelled due to an exception
# The book number: 896 was cancelled due to an exception
# The book number: 897 was cancelled due to an exception
# The book number: 898 was cancelled due to an exception
# The book number: 899 was cancelled due to an exception
# The book number: 900 was cancelled due to an exception
# The book number: 901 was cancelled due to an exception
# The book number: 902 was cancelled due to an exception
# The book number: 903 was cancelled due to an exception
# The book number: 904 was cancelled due to an exception
# The book number: 905 was cancelled due to an exception
# The book number: 906 was cancelled due to an exception
# The book number: 907 was cancelled due to an exception
# The book number: 908 was cancelled due to an exception
# The book number: 909 was cancelled due to an exception
# The book number: 910 was cancelled due to an exception
# The book number: 911 was cancelled due to an exception
# The book number: 912 was cancelled due to an exception
# The book number: 913 was cancelled due to an exception
# The book number: 914 was cancelled due to an exception
# The book number: 915 was cancelled due to an exception
# The book number: 916 was cancelled due to an exception
# The book number: 917 was cancelled due to an exception
# The book number: 918 was cancelled due to an exception
# The book number: 919 was cancelled due to an exception
# The book number: 920 was cancelled due to an exception
# The book number: 921 was cancelled due to an exception
# The book number: 922 was cancelled due to an exception
# The book number: 923 was cancelled due to an exception
# The book number: 924 was cancelled due to an exception
# The book number: 925 was cancelled due to an exception
# The book number: 926 was cancelled due to an exception
# The book number: 927 was cancelled due to an exception
# The book number: 928 was cancelled due to an exception
# The book number: 929 was cancelled due to an exception
# The book number: 930 was cancelled due to an exception
# The book number: 931 was cancelled due to an exception
# The book number: 932 was cancelled due to an exception
# The book number: 933 was cancelled due to an exception
# The book number: 934 was cancelled due to an exception
# The book number: 935 was cancelled due to an exception
# The book number: 936 was cancelled due to an exception
# The book number: 937 was cancelled due to an exception
# The book number: 938 was cancelled due to an exception
# The book number: 939 was cancelled due to an exception
# The book number: 940 was cancelled due to an exception
# The book number: 941 was cancelled due to an exception
# The book number: 942 was cancelled due to an exception
# The book number: 943 was cancelled due to an exception
# The book number: 944 was cancelled due to an exception
# The book number: 945 was cancelled due to an exception
# The book number: 946 was cancelled due to an exception
# The book number: 947 was cancelled due to an exception
# The book number: 948 was cancelled due to an exception
# The book number: 949 was cancelled due to an exception
# The book number: 950 was cancelled due to an exception
# The book number: 951 was cancelled due to an exception
# The book number: 952 was cancelled due to an exception
# The book number: 953 was cancelled due to an exception
# The book number: 954 was cancelled due to an exception
# The book number: 955 was cancelled due to an exception
# The book number: 956 was cancelled due to an exception
# The book number: 957 was cancelled due to an exception
# The book number: 958 was cancelled due to an exception
# The book number: 959 was cancelled due to an exception
# The book number: 960 was cancelled due to an exception
# The book number: 961 was cancelled due to an exception
# The book number: 962 was cancelled due to an exception
# The book number: 963 was cancelled due to an exception
# The book number: 964 was cancelled due to an exception
# The book number: 965 was cancelled due to an exception
# The book number: 966 was cancelled due to an exception
# The book number: 967 was cancelled due to an exception
# The book number: 968 was cancelled due to an exception
# The book number: 969 was cancelled due to an exception
# The book number: 970 was cancelled due to an exception
# The book number: 971 was cancelled due to an exception
# The book number: 972 was cancelled due to an exception
# The book number: 973 was cancelled due to an exception
# The book number: 974 was cancelled due to an exception
# The book number: 975 was cancelled due to an exception
# The book number: 976 was cancelled due to an exception
# The book number: 977 was cancelled due to an exception
# The book number: 978 was cancelled due to an exception
# The book number: 979 was cancelled due to an exception
# The book number: 980 was cancelled due to an exception
# The book number: 981 was cancelled due to an exception
# The book number: 982 was cancelled due to an exception
# The book number: 983 was cancelled due to an exception
# The book number: 984 was cancelled due to an exception
# The book number: 985 was cancelled due to an exception
# The book number: 986 was cancelled due to an exception
# The book number: 987 was cancelled due to an exception
# The book number: 988 was cancelled due to an exception
# The book number: 989 was cancelled due to an exception
# The book number: 990 was cancelled due to an exception
# The book number: 991 was cancelled due to an exception
# The book number: 992 was cancelled due to an exception
# The book number: 993 was cancelled due to an exception
# The book number: 994 was cancelled due to an exception
# The book number: 995 was cancelled due to an exception
# The book number: 996 was cancelled due to an exception
# The book number: 997 was cancelled due to an exception
# The book number: 998 was cancelled due to an exception
# The book number: 999 was cancelled due to an exception
# The book number: 1000 was cancelled due to an exception
# The book number: 1001 was cancelled due to an exception
# The book number: 1002 was cancelled due to an exception
# The book number: 1003 was cancelled due to an exception
# The book number: 1004 was cancelled due to an exception
# The book number: 1005 was cancelled due to an exception
# The book number: 1006 was cancelled due to an exception
# The book number: 1007 was cancelled due to an exception
# The book number: 1008 was cancelled due to an exception
# The book number: 1009 was cancelled due to an exception
# The book number: 1010 was cancelled due to an exception
# The book number: 1011 was cancelled due to an exception
# The book number: 1012 was cancelled due to an exception
# The book number: 1013 was cancelled due to an exception
# The book number: 1014 was cancelled due to an exception
# The book number: 1015 was cancelled due to an exception
# The book number: 1016 was cancelled due to an exception
# The book number: 1017 was cancelled due to an exception
# The book number: 1018 was cancelled due to an exception
# The book number: 1019 was cancelled due to an exception
# The book number: 1020 was cancelled due to an exception
# The book number: 1021 was cancelled due to an exception
# The book number: 1022 was cancelled due to an exception
# The book number: 1023 was cancelled due to an exception
# The book number: 1024 was cancelled due to an exception
# The book number: 1025 was cancelled due to an exception
# The book number: 1026 was cancelled due to an exception
# The book number: 1027 was cancelled due to an exception
# The book number: 1028 was cancelled due to an exception
# The book number: 1029 was cancelled due to an exception
# The book number: 1030 was cancelled due to an exception
# The book number: 1031 was cancelled due to an exception
# The book number: 1032 was cancelled due to an exception
# The book number: 1033 was cancelled due to an exception
# The book number: 1034 was cancelled due to an exception
# The book number: 1035 was cancelled due to an exception
# The book number: 1036 was cancelled due to an exception
# The book number: 1037 was cancelled due to an exception
# The book number: 1038 was cancelled due to an exception
# The book number: 1039 was cancelled due to an exception
# The book number: 1040 was cancelled due to an exception
# The book number: 1041 was cancelled due to an exception
# The book number: 1042 was cancelled due to an exception
# The book number: 1043 was cancelled due to an exception
# The book number: 1044 was cancelled due to an exception
# The book number: 1045 was cancelled due to an exception
# The book number: 1046 was cancelled due to an exception
# The book number: 1047 was cancelled due to an exception
# The book number: 1048 was cancelled due to an exception
# The book number: 1049 was cancelled due to an exception
# The book number: 1050 was cancelled due to an exception
# The book number: 1051 was cancelled due to an exception
# The book number: 1052 was cancelled due to an exception
# The book number: 1053 was cancelled due to an exception
# The book number: 1054 was cancelled due to an exception
# The book number: 1055 was cancelled due to an exception
# The book number: 1056 was cancelled due to an exception
# The book number: 1057 was cancelled due to an exception
# The book number: 1058 was cancelled due to an exception
# The book number: 1059 was cancelled due to an exception
# The book number: 1060 was cancelled due to an exception
# The book number: 1061 was cancelled due to an exception
# The book number: 1062 was cancelled due to an exception
# The book number: 1063 was cancelled due to an exception
# The book number: 1064 was cancelled due to an exception
# The book number: 1065 was cancelled due to an exception
# The book number: 1066 was cancelled due to an exception
# The book number: 1067 was cancelled due to an exception
# The book number: 1068 was cancelled due to an exception
# The book number: 1069 was cancelled due to an exception
# The book number: 1070 was cancelled due to an exception
# The book number: 1071 was cancelled due to an exception
# The book number: 1072 was cancelled due to an exception
# The book number: 1073 was cancelled due to an exception
# The book number: 1074 was cancelled due to an exception
# The book number: 1075 was cancelled due to an exception
# The book number: 1076 was cancelled due to an exception
# The book number: 1077 was cancelled due to an exception
# The book number: 1078 was cancelled due to an exception
# The book number: 1079 was cancelled due to an exception
# The book number: 1080 was cancelled due to an exception
# The book number: 1081 was cancelled due to an exception
# The book number: 1082 was cancelled due to an exception
# The book number: 1083 was cancelled due to an exception
# The book number: 1084 was cancelled due to an exception
# The book number: 1085 was cancelled due to an exception
# The book number: 1086 was cancelled due to an exception
# The book number: 1087 was cancelled due to an exception
# The book number: 1088 was cancelled due to an exception
# The book number: 1089 was cancelled due to an exception
# The book number: 1090 was cancelled due to an exception
# The book number: 1091 was cancelled due to an exception
# The book number: 1092 was cancelled due to an exception
# The book number: 1093 was cancelled due to an exception
# The book number: 1094 was cancelled due to an exception
# The book number: 1095 was cancelled due to an exception
# The book number: 1096 was cancelled due to an exception
# The book number: 1097 was cancelled due to an exception
# The book number: 1098 was cancelled due to an exception
# The book number: 1099 was cancelled due to an exception
# The book number: 1100 was cancelled due to an exception
# The book number: 1101 was cancelled due to an exception
# The book number: 1102 was cancelled due to an exception
# The book number: 1103 was cancelled due to an exception
# The book number: 1104 was cancelled due to an exception
# The book number: 1105 was cancelled due to an exception
# The book number: 1106 was cancelled due to an exception
# The book number: 1107 was cancelled due to an exception
# The book number: 1108 was cancelled due to an exception
# The book number: 1109 was cancelled due to an exception
# The book number: 1110 was cancelled due to an exception
# The book number: 1111 was cancelled due to an exception
# The book number: 1112 was cancelled due to an exception
# The book number: 1113 was cancelled due to an exception
# The book number: 1114 was cancelled due to an exception
# The book number: 1115 was cancelled due to an exception
# The book number: 1116 was cancelled due to an exception
# The book number: 1117 was cancelled due to an exception
# The book number: 1118 was cancelled due to an exception
# The book number: 1119 was cancelled due to an exception
# The book number: 1120 was cancelled due to an exception
# The book number: 1121 was cancelled due to an exception
# The book number: 1122 was cancelled due to an exception
# The book number: 1123 was cancelled due to an exception
# The book number: 1124 was cancelled due to an exception
# The book number: 1125 was cancelled due to an exception
# The book number: 1126 was cancelled due to an exception
# The book number: 1127 was cancelled due to an exception
# The book number: 1128 was cancelled due to an exception
# The book number: 1129 was cancelled due to an exception
# The book number: 1130 was cancelled due to an exception
# The book number: 1131 was cancelled due to an exception
# The book number: 1132 was cancelled due to an exception
# The book number: 1133 was cancelled due to an exception
# The book number: 1134 was cancelled due to an exception
# The book number: 1135 was cancelled due to an exception
# The book number: 1136 was cancelled due to an exception
# The book number: 1137 was cancelled due to an exception
# The book number: 1138 was cancelled due to an exception
# The book number: 1139 was cancelled due to an exception
# The book number: 1140 was cancelled due to an exception
# The book number: 1141 was cancelled due to an exception
# The book number: 1142 was cancelled due to an exception
# The book number: 1143 was cancelled due to an exception
# The book number: 1144 was cancelled due to an exception
# The book number: 1145 was cancelled due to an exception
# The book number: 1146 was cancelled due to an exception
# The book number: 1147 was cancelled due to an exception
# The book number: 1148 was cancelled due to an exception
# The book number: 1149 was cancelled due to an exception
# The book number: 1150 was cancelled due to an exception
# The book number: 1151 was cancelled due to an exception
# The book number: 1152 was cancelled due to an exception
# The book number: 1153 was cancelled due to an exception
# The book number: 1154 was cancelled due to an exception
# The book number: 1155 was cancelled due to an exception
# The book number: 1156 was cancelled due to an exception
# The book number: 1157 was cancelled due to an exception
# The book number: 1158 was cancelled due to an exception
# The book number: 1159 was cancelled due to an exception
# The book number: 1160 was cancelled due to an exception
# The book number: 1161 was cancelled due to an exception
# The book number: 1162 was cancelled due to an exception
# The book number: 1163 was cancelled due to an exception
# The book number: 1164 was cancelled due to an exception
# The book number: 1165 was cancelled due to an exception
# The book number: 1166 was cancelled due to an exception
# The book number: 1167 was cancelled due to an exception
# The book number: 1168 was cancelled due to an exception
# The book number: 1169 was cancelled due to an exception
# The book number: 1170 was cancelled due to an exception
# The book number: 1171 was cancelled due to an exception
# The book number: 1172 was cancelled due to an exception
# The book number: 1173 was cancelled due to an exception
# The book number: 1174 was cancelled due to an exception
# The book number: 1175 was cancelled due to an exception
# The book number: 1176 was cancelled due to an exception
# The book number: 1177 was cancelled due to an exception
# The book number: 1178 was cancelled due to an exception
# The book number: 1179 was cancelled due to an exception
# The book number: 1180 was cancelled due to an exception
# The book number: 1181 was cancelled due to an exception
# The book number: 1182 was cancelled due to an exception
# The book number: 1183 was cancelled due to an exception
# The book number: 1184 was cancelled due to an exception
# The book number: 1185 was cancelled due to an exception
# The book number: 1186 was cancelled due to an exception
# The book number: 1187 was cancelled due to an exception
# The book number: 1188 was cancelled due to an exception
# The book number: 1189 was cancelled due to an exception
# The book number: 1190 was cancelled due to an exception
# The book number: 1191 was cancelled due to an exception
# The book number: 1192 was cancelled due to an exception
# The book number: 1193 was cancelled due to an exception
# The book number: 1194 was cancelled due to an exception
# The book number: 1195 was cancelled due to an exception
# The book number: 1196 was cancelled due to an exception
# The book number: 1197 was cancelled due to an exception
# The book number: 1198 was cancelled due to an exception
# The book number: 1199 was cancelled due to an exception
# The book number: 1200 was cancelled due to an exception
# The book number: 1201 was cancelled due to an exception
# The book number: 1202 was cancelled due to an exception
# The book number: 1203 was cancelled due to an exception
# The book number: 1204 was cancelled due to an exception
# The book number: 1205 was cancelled due to an exception
# The book number: 1206 was cancelled due to an exception
# The book number: 1207 was cancelled due to an exception
# The book number: 1208 was cancelled due to an exception
# The book number: 1209 was cancelled due to an exception
# The book number: 1210 was cancelled due to an exception
# The book number: 1211 was cancelled due to an exception
# The book number: 1212 was cancelled due to an exception
# The book number: 1213 was cancelled due to an exception
# The book number: 1214 was cancelled due to an exception
# The book number: 1215 was cancelled due to an exception
# The book number: 1216 was cancelled due to an exception
# The book number: 1217 was cancelled due to an exception
# The book number: 1218 was cancelled due to an exception
# The book number: 1219 was cancelled due to an exception
# The book number: 1220 was cancelled due to an exception
# The book number: 1221 was cancelled due to an exception
# The book number: 1222 was cancelled due to an exception
# The book number: 1223 was cancelled due to an exception
# The book number: 1224 was cancelled due to an exception
# The book number: 1225 was cancelled due to an exception
# The book number: 1226 was cancelled due to an exception
# The book number: 1227 was cancelled due to an exception
# The book number: 1228 was cancelled due to an exception
# The book number: 1229 was cancelled due to an exception
# The book number: 1230 was cancelled due to an exception
# The book number: 1231 was cancelled due to an exception
# The book number: 1232 was cancelled due to an exception
# The book number: 1233 was cancelled due to an exception
# The book number: 1234 was cancelled due to an exception
# The book number: 1235 was cancelled due to an exception
# The book number: 1236 was cancelled due to an exception
# The book number: 1237 was cancelled due to an exception
# The book number: 1238 was cancelled due to an exception
# The book number: 1239 was cancelled due to an exception
# The book number: 1240 was cancelled due to an exception
# The book number: 1241 was cancelled due to an exception
# The book number: 1242 was cancelled due to an exception
# The book number: 1243 was cancelled due to an exception
# The book number: 1244 was cancelled due to an exception
# The book number: 1245 was cancelled due to an exception
# The book number: 1246 was cancelled due to an exception
# The book number: 1247 was cancelled due to an exception
# The book number: 1248 was cancelled due to an exception
# The book number: 1249 was cancelled due to an exception
# The book number: 1250 was cancelled due to an exception
# The book number: 1251 was cancelled due to an exception

# %% [markdown]
# ## Method 2: Scrape using lists of books urls

# %%
# Read the text file 
textFile = open("Data/Lists_of_Links/list_of_urls10.txt", "r")
list_of_urls = textFile.read()
# Convert it into a list
list_of_urls = list_of_urls.split(",")
textFile.close()

# %%
len(list_of_urls)
# Out:
# 31901

# %%
# ================= Scrape each book by its url within a specific category =================
book_index = 1360
while book_index < len(list_of_urls):
    # Open the book link
    try:
        browser.get(list_of_urls[book_index][2:-1]) # there are additional space and qoutation mark, we need to remove them.
        # Call a function to scrape each book metadata by pass the previous list
        book_scraper(book_index)
    except:
        print("The book number: ", book_index, 'was cancelled due to an exception with the link')
    book_index += 1
# Out:
# ================= Book number:  1360  was successfully scraped =================
# ================= Book number:  1361  was successfully scraped =================
# ================= Book number:  1362  was successfully scraped =================
# ================= Book number:  1363  was successfully scraped =================
# ================= Book number:  1364  was successfully scraped =================
# ================= Book number:  1365  was successfully scraped =================
# ================= Book number:  1366  was successfully scraped =================
# ================= Book number:  1367  was successfully scraped =================
# ================= Book number:  1368  was successfully scraped =================
# ================= Book number:  1369  was successfully scraped =================
# ================= Book number:  1370  was successfully scraped =================
# ================= Book number:  1371  was successfully scraped =================
# ================= Book number:  1372  was successfully scraped =================
# ================= Book number:  1373  was successfully scraped =================
# ================= Book number:  1374  was successfully scraped =================
# ================= Book number:  1375  was successfully scraped =================
# ================= Book number:  1376  was successfully scraped =================
# ================= Book number:  1377  was successfully scraped =================
# ================= Book number:  1378  was successfully scraped =================
# ================= Book number:  1379  was successfully scraped =================
# ================= Book number:  1380  was successfully scraped =================
# ================= Book number:  1381  was successfully scraped =================
# ================= Book number:  1382  was successfully scraped =================
# ================= Book number:  1383  was successfully scraped =================
# ================= Book number:  1384  was successfully scraped =================
# ================= Book number:  1385  was successfully scraped =================
# ================= Book number:  1386  was successfully scraped =================
# ================= Book number:  1387  was successfully scraped =================
# ================= Book number:  1388  was successfully scraped =================
# ================= Book number:  1389  was successfully scraped =================
# ================= Book number:  1390  was successfully scraped =================
# ================= Book number:  1391  was successfully scraped =================
# ================= Book number:  1392  was successfully scraped =================
# ================= Book number:  1393  was successfully scraped =================
# ================= Book number:  1394  was successfully scraped =================
# ================= Book number:  1395  was successfully scraped =================
# ================= Book number:  1396  was successfully scraped =================
# ================= Book number:  1397  was successfully scraped =================
# ================= Book number:  1398  was successfully scraped =================
# ================= Book number:  1399  was successfully scraped =================
# ================= Book number:  1400  was successfully scraped =================
# ================= Book number:  1401  was successfully scraped =================
# ================= Book number:  1402  was successfully scraped =================
# ================= Book number:  1403  was successfully scraped =================
# ================= Book number:  1404  was successfully scraped =================
# ================= Book number:  1405  was successfully scraped =================
# ================= Book number:  1406  was successfully scraped =================
# ================= Book number:  1407  was successfully scraped =================
# ================= Book number:  1408  was successfully scraped =================
# ================= Book number:  1409  was successfully scraped =================
# ================= Book number:  1410  was successfully scraped =================
# ================= Book number:  1411  was successfully scraped =================
# ================= Book number:  1412  was successfully scraped =================
# ================= Book number:  1413  was successfully scraped =================
# ================= Book number:  1414  was successfully scraped =================
# ================= Book number:  1415  was successfully scraped =================
# ================= Book number:  1416  was successfully scraped =================
# ================= Book number:  1417  was successfully scraped =================
# ================= Book number:  1418  was successfully scraped =================
# ================= Book number:  1419  was successfully scraped =================
# ================= Book number:  1420  was successfully scraped =================
# ================= Book number:  1421  was successfully scraped =================
# ================= Book number:  1422  was successfully scraped =================
# ================= Book number:  1423  was successfully scraped =================
# ================= Book number:  1424  was successfully scraped =================
# ================= Book number:  1425  was successfully scraped =================
# ================= Book number:  1426  was successfully scraped =================
# ================= Book number:  1427  was successfully scraped =================
# ================= Book number:  1428  was successfully scraped =================
# ================= Book number:  1429  was successfully scraped =================
# ================= Book number:  1430  was successfully scraped =================
# ================= Book number:  1431  was successfully scraped =================
# ================= Book number:  1432  was successfully scraped =================
# ================= Book number:  1433  was successfully scraped =================
# ================= Book number:  1434  was successfully scraped =================
# ================= Book number:  1435  was successfully scraped =================
# ================= Book number:  1436  was successfully scraped =================
# ================= Book number:  1437  was successfully scraped =================
# ================= Book number:  1438  was successfully scraped =================
# ================= Book number:  1439  was successfully scraped =================
# ================= Book number:  1440  was successfully scraped =================
# ================= Book number:  1441  was successfully scraped =================
# ================= Book number:  1442  was successfully scraped =================
# ================= Book number:  1443  was successfully scraped =================
# ================= Book number:  1444  was successfully scraped =================
# ================= Book number:  1445  was successfully scraped =================
# ================= Book number:  1446  was successfully scraped =================
# ================= Book number:  1447  was successfully scraped =================
# ================= Book number:  1448  was successfully scraped =================
# ================= Book number:  1449  was successfully scraped =================
# ================= Book number:  1450  was successfully scraped =================
# ================= Book number:  1451  was successfully scraped =================
# ================= Book number:  1452  was successfully scraped =================
# ================= Book number:  1453  was successfully scraped =================
# ================= Book number:  1454  was successfully scraped =================
# ================= Book number:  1455  was successfully scraped =================
# ================= Book number:  1456  was successfully scraped =================
# ================= Book number:  1457  was successfully scraped =================
# ================= Book number:  1458  was successfully scraped =================
# ================= Book number:  1459  was successfully scraped =================
# ================= Book number:  1460  was successfully scraped =================
# ================= Book number:  1461  was successfully scraped =================
# ================= Book number:  1462  was successfully scraped =================
# ================= Book number:  1463  was successfully scraped =================
# ================= Book number:  1464  was successfully scraped =================
# ================= Book number:  1465  was successfully scraped =================
# ================= Book number:  1466  was successfully scraped =================
# ================= Book number:  1467  was successfully scraped =================
# ================= Book number:  1468  was successfully scraped =================
# ================= Book number:  1469  was successfully scraped =================
# ================= Book number:  1470  was successfully scraped =================
# ================= Book number:  1471  was successfully scraped =================
# ================= Book number:  1472  was successfully scraped =================
# ================= Book number:  1473  was successfully scraped =================
# ================= Book number:  1474  was successfully scraped =================
# ================= Book number:  1475  was successfully scraped =================
# ================= Book number:  1476  was successfully scraped =================
# ================= Book number:  1477  was successfully scraped =================
# ================= Book number:  1478  was successfully scraped =================
# ================= Book number:  1479  was successfully scraped =================
# ================= Book number:  1480  was successfully scraped =================
# ================= Book number:  1481  was successfully scraped =================
# ================= Book number:  1482  was successfully scraped =================
# ================= Book number:  1483  was successfully scraped =================
# ================= Book number:  1484  was successfully scraped =================
# ================= Book number:  1485  was successfully scraped =================
# ================= Book number:  1486  was successfully scraped =================
# ================= Book number:  1487  was successfully scraped =================
# ================= Book number:  1488  was successfully scraped =================
# ================= Book number:  1489  was successfully scraped =================
# ================= Book number:  1490  was successfully scraped =================
# ================= Book number:  1491  was successfully scraped =================
# ================= Book number:  1492  was successfully scraped =================
# ================= Book number:  1493  was successfully scraped =================
# ================= Book number:  1494  was successfully scraped =================
# ================= Book number:  1495  was successfully scraped =================
# ================= Book number:  1496  was successfully scraped =================
# ================= Book number:  1497  was successfully scraped =================
# ================= Book number:  1498  was successfully scraped =================
# ================= Book number:  1499  was successfully scraped =================
# ================= Book number:  1500  was successfully scraped =================
# ================= Book number:  1501  was successfully scraped =================
# ================= Book number:  1502  was successfully scraped =================
# ================= Book number:  1503  was successfully scraped =================
# ================= Book number:  1504  was successfully scraped =================
# ================= Book number:  1505  was successfully scraped =================
# ================= Book number:  1506  was successfully scraped =================
# ================= Book number:  1507  was successfully scraped =================
# ================= Book number:  1508  was successfully scraped =================
# ================= Book number:  1509  was successfully scraped =================
# ================= Book number:  1510  was successfully scraped =================
# ================= Book number:  1511  was successfully scraped =================
# ================= Book number:  1512  was successfully scraped =================
# ================= Book number:  1513  was successfully scraped =================
# ================= Book number:  1514  was successfully scraped =================
# ================= Book number:  1515  was successfully scraped =================
# ================= Book number:  1516  was successfully scraped =================
# ================= Book number:  1517  was successfully scraped =================
# ================= Book number:  1518  was successfully scraped =================
# ================= Book number:  1519  was successfully scraped =================
# ================= Book number:  1520  was successfully scraped =================
# ================= Book number:  1521  was successfully scraped =================
# ================= Book number:  1522  was successfully scraped =================
# ================= Book number:  1523  was successfully scraped =================
# ================= Book number:  1524  was successfully scraped =================
# ================= Book number:  1525  was successfully scraped =================
# ================= Book number:  1526  was successfully scraped =================
# ================= Book number:  1527  was successfully scraped =================
# ================= Book number:  1528  was successfully scraped =================
# ================= Book number:  1529  was successfully scraped =================
# ================= Book number:  1530  was successfully scraped =================
# ================= Book number:  1531  was successfully scraped =================
# ================= Book number:  1532  was successfully scraped =================
# ================= Book number:  1533  was successfully scraped =================
# ================= Book number:  1534  was successfully scraped =================
# ================= Book number:  1535  was successfully scraped =================
# ================= Book number:  1536  was successfully scraped =================
# ================= Book number:  1537  was successfully scraped =================
# ================= Book number:  1538  was successfully scraped =================
# ================= Book number:  1539  was successfully scraped =================
# ================= Book number:  1540  was successfully scraped =================
# ================= Book number:  1541  was successfully scraped =================
# ================= Book number:  1542  was successfully scraped =================
# ================= Book number:  1543  was successfully scraped =================
# ================= Book number:  1544  was successfully scraped =================
# ================= Book number:  1545  was successfully scraped =================
# ================= Book number:  1546  was successfully scraped =================
# ================= Book number:  1547  was successfully scraped =================
# ================= Book number:  1548  was successfully scraped =================
# ================= Book number:  1549  was successfully scraped =================
# ================= Book number:  1550  was successfully scraped =================
# ================= Book number:  1551  was successfully scraped =================
# ================= Book number:  1552  was successfully scraped =================
# ================= Book number:  1553  was successfully scraped =================
# ================= Book number:  1554  was successfully scraped =================
# ================= Book number:  1555  was successfully scraped =================
# ================= Book number:  1556  was successfully scraped =================
# ================= Book number:  1557  was successfully scraped =================
# ---------------------------------------------------------------------------
# InvalidArgumentException                  Traceback (most recent call last)
# <ipython-input-27-82147347748f> in <module>
#       4     #print(list_of_urls[book_index][1:])
#       5     # Open the book link
# ----> 6     browser.get(list_of_urls[book_index][2:-1]) # there are additional space and qoutation mark, we need to remove them.
#       7     # Call a function to scrape each book metadata by pass the previous list
#       8     book_scraper(book_index)
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# InvalidArgumentException: Message: Malformed URL: URL constructor: on is not a valid URL.

# %% [markdown]
# ## Overview of the resulted dataframe

# %%
books_dataset.shape
# Out:
# (198, 16)

# %%
books_dataset.head()
# Out:
#                               ISBN                               Title  \
# 0            ISBN 13 9789953895697                      روايتي لروايتي
# 1        ISBN 13 978-977-6765-14-7                      امرأة من طهران
# 2            ISBN 13 9789953211961  مختارات #5: في صحبة المتنبي ورفاقه
# 3  المؤسسة العربية للدراسات والنشر                     حين تركنا الجسر
# 4                  ISBN 9960497887                       متعة الحديث 1
#
#                                               Author Authors_Number  \
# 0                            تأليف سحر خليفة (تأليف)    المؤلفون\n1
# 1  تأليف فريبا وفي (تأليف) المترجم أحمد موسى (ترجمة)    المؤلفون\n2
# 2                           تأليف الطيب صالح (تأليف)    المؤلفون\n1
# 3                      تأليف عبد الرحمن منيف (تأليف)    المؤلفون\n1
# 4                تأليف عبد الله محمد الداوود (تأليف)    المؤلفون\n1
#
#                                          Description  \
# 0  الأديب، كأيِّ إنسان، ابن البيئة. وهي، أي البيئ...
# 1  امرأة من طهران تروي حياة النساء حبيسات الجدران...
# 2  أي صحبة خير من صحبة أبي الطيب المتنبي الذي شغل...
# 3  "أية مشاعر للفرح يحملها قلب الإنسان؟ أية غبطة ...
# 4  متعة الحديث مجموعة مكونة من كتابين ذكر فيها ال...
#
#                             Genres Average_Ratings Reviews_Number  \
# 0                أدب مختارات أدبية             3.3     مراجعات\n2
# 1  أدب أدب مترجم إضافات جديدة جديد               4     مراجعات\n2
# 2                     أدب نقد أدبي             4.8     مراجعات\n1
# 3                       أدب روايات             3.8     مراجعات\n8
# 4                أدب مختارات أدبية             3.8     مراجعات\n1
#
#   Quotes_Number Community_Size Pages_Number  Editions Publication_Year  \
# 0  اقتباسات\n12    القرّاء\n76     366 صفحة  طبعات\n1     نشر سنة 2018
# 1   اقتباسات\n2    القرّاء\n76     254 صفحة  طبعات\n1     نشر سنة 2020
# 2   اقتباسات\n5    القرّاء\n75     442 صفحة  طبعات\n1     نشر سنة 2005
# 3   اقتباسات\n5    القرّاء\n75     217 صفحة  طبعات\n1     نشر سنة 1999
# 4  اقتباسات\n12    القرّاء\n75     314 صفحة  طبعات\n1     نشر سنة 2006
#
#                      Publisher  \
# 0                   دار الآداب
# 1               منشورات الربيع
# 2  دار رياض الريس للكتب والنشر
# 3                         None
# 4                         None
#
#                                                  URL  \
# 0  https://www.abjjad.com/book/2710601731/%D8%B1%...
# 1  https://www.abjjad.com/book/2735898624/%D8%A7%...
# 2  https://www.abjjad.com/book/15445051/%D9%85%D8...
# 3  https://www.abjjad.com/book/15445384/%D8%AD%D9...
# 4  https://www.abjjad.com/book/15446139/%D9%85%D8...
#
#                                            Cover_URL
# 0  https://abjjadst.blob.core.windows.net/pub/792...
# 1  https://abjjadst.blob.core.windows.net/pub/7e9...
# 2  https://abjjadst.blob.core.windows.net/pub/5a9...
# 3  https://abjjadst.blob.core.windows.net/pub/395...
# 4  https://abjjadst.blob.core.windows.net/pub/77b...
